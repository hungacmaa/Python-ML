# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("diem-after-cleaning.csv")
# split into input (X) and output (Y) variables
dataset.drop(['Unnamed: 0'], axis=1, inplace=True)
dataset
# Out:
#         P1    P2    P3   Thi
# 0    8.375  7.25  8.50   9.0
# 1    8.250  7.25  8.50   9.0
# 2    8.500  7.50  8.50  10.0
# 3    4.000  7.25  8.50   9.0
# 4    8.750  7.50  8.50   9.5
# ..     ...   ...   ...   ...
# 292  5.500  6.75  6.75   6.5
# 293  7.000  6.25  7.00   6.0
# 294  4.000  6.25  7.00   6.0
# 295  7.500  8.00  7.00   7.0
# 296  3.500  5.50  3.00   5.0
#
# [297 rows x 4 columns]

# %%
dataset = dataset.values
dataset
# Out:
# array([[ 8.375,  7.25 ,  8.5  ,  9.   ],
#        [ 8.25 ,  7.25 ,  8.5  ,  9.   ],
#        [ 8.5  ,  7.5  ,  8.5  , 10.   ],
#        ...,
#        [ 4.   ,  6.25 ,  7.   ,  6.   ],
#        [ 7.5  ,  8.   ,  7.   ,  7.   ],
#        [ 3.5  ,  5.5  ,  3.   ,  5.   ]])

# %%
X = dataset[:,0:3]
Y = dataset[:,3]

# %%
X
# Out:
# array([[ 8.375     ,  7.25      ,  8.5       ],
#        [ 8.25      ,  7.25      ,  8.5       ],
#        [ 8.5       ,  7.5       ,  8.5       ],
#        [ 4.        ,  7.25      ,  8.5       ],
#        [ 8.75      ,  7.5       ,  8.5       ],
#        [ 7.75      ,  7.75      ,  7.75      ],
#        [ 7.        ,  3.        ,  7.        ],
#        [ 7.5       ,  7.5       ,  7.5       ],
#        [ 7.        ,  7.        ,  7.        ],
#        [ 7.25      ,  7.        ,  7.        ],
#        [ 7.625     ,  7.25      ,  7.        ],
#        [ 7.75      ,  7.25      ,  7.25      ],
#        [ 7.625     ,  7.375     ,  7.75      ],
#        [ 7.5       ,  6.5       ,  6.75      ],
#        [ 7.5       ,  7.25      ,  7.        ],
#        [ 8.5       ,  8.        ,  9.        ],
#        [ 8.125     ,  7.625     ,  7.5       ],
#        [ 8.125     ,  7.625     ,  7.75      ],
#        [ 8.25      ,  7.875     ,  8.        ],
#        [ 8.        ,  7.25      ,  8.25      ],
# ...

# %%
Y
# Out:
# array([ 9.        ,  9.        , 10.        ,  9.        ,  9.5       ,
#         7.5       ,  7.        ,  7.5       ,  7.        ,  7.5       ,
#         7.25      ,  7.5       ,  7.5       ,  7.        ,  7.25      ,
#         9.        ,  7.75      ,  7.75      ,  7.5       ,  8.        ,
#         7.5       ,  8.        ,  0.        ,  8.5       ,  8.        ,
#         7.5       ,  7.5       ,  7.        ,  7.        ,  7.25      ,
#         7.        ,  7.5       ,  7.        ,  8.        ,  7.5       ,
#         8.        ,  8.        ,  8.        ,  8.25      ,  8.        ,
#         8.        ,  7.25      ,  7.        ,  6.5       ,  0.        ,
#         7.5       ,  7.5       ,  8.        ,  7.5       ,  7.75      ,
#         7.75      ,  7.5       ,  7.5       ,  7.5       ,  7.75      ,
#         6.5       ,  8.        ,  8.        ,  9.        ,  8.        ,
#         0.        ,  7.        ,  0.        ,  6.        ,  7.        ,
# ...

# %%
model = Sequential()
model.add(Dense(12, input_dim=3, activation='relu'))
model.add(Dense(8, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
history = model.fit(X, Y, validation_split=0.33, epochs=150, batch_size=10, verbose=0)

# %%
print(history.history.keys())
# summarize history f
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
model = Sequential()
model.add(Dense(8, input_dim=3, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.20, epochs=50, batch_size=10, verbose=0)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model = Sequential()
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.3, epochs=50, batch_size=20, verbose=0)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model = Sequential()
model.add(Dense(8,input_dim=3, activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.3, epochs=10, batch_size=50, verbose=0)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model = Sequential()
model.add(Dense(8,input_dim=3, activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.3, epochs=10, batch_size=32, verbose=0)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model = Sequential()
model.add(Dense(8,input_dim=3, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.24, epochs=30, batch_size=20)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/30
# 12/12 [==============================] - 1s 15ms/step - loss: -46.5386 - accuracy: 0.0000e+00 - val_loss: -50.6027 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 12/12 [==============================] - 0s 3ms/step - loss: -51.2567 - accuracy: 0.0000e+00 - val_loss: -55.6708 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 12/12 [==============================] - 0s 3ms/step - loss: -56.2900 - accuracy: 0.0000e+00 - val_loss: -61.1090 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 12/12 [==============================] - 0s 3ms/step - loss: -61.5920 - accuracy: 0.0000e+00 - val_loss: -66.8158 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 12/12 [==============================] - 0s 3ms/step - loss: -67.2304 - accuracy: 0.0000e+00 - val_loss: -72.6791 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 12/12 [==============================] - 0s 3ms/step - loss: -73.0364 - accuracy: 0.0000e+00 - val_loss: -78.8424 - val_accuracy: 0.0000e+00
# Epoch 7/30
# ...

# %%
model = Sequential()
model.add(Dense(8,input_dim=3, activation='relu'))
model.add(Dense(7, activation='relu'))
model.add(Dense(6, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.24, epochs=30, batch_size=30)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/30
# 8/8 [==============================] - 1s 26ms/step - loss: -24.7656 - accuracy: 0.0000e+00 - val_loss: -28.5040 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 8/8 [==============================] - 0s 5ms/step - loss: -28.8889 - accuracy: 0.0000e+00 - val_loss: -33.0492 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 8/8 [==============================] - 0s 4ms/step - loss: -33.3567 - accuracy: 0.0000e+00 - val_loss: -37.9241 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 8/8 [==============================] - 0s 5ms/step - loss: -38.0834 - accuracy: 0.0000e+00 - val_loss: -43.1938 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 8/8 [==============================] - 0s 4ms/step - loss: -43.2243 - accuracy: 0.0000e+00 - val_loss: -49.0039 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 8/8 [==============================] - 0s 4ms/step - loss: -48.8923 - accuracy: 0.0000e+00 - val_loss: -55.4991 - val_accuracy: 0.0000e+00
# Epoch 7/30
# ...

# %%
model = Sequential()
model.add(Dense(1,input_dim=3, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.24, epochs=30, batch_size=10, verbose=0)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model = Sequential()
model.add(Dense(1,input_dim=3, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.24, epochs=30, batch_size=30, verbose=0)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
model = Sequential()
model.add(Dense(5, input_dim=3, activation='relu'))
model.add(Dense(4, activation='relu'))
model.add(Dense(3, activation='relu'))
model.add(Dense(1, activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.2, epochs=100, batch_size=10)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# Epoch 1/100
# 24/24 [==============================] - 1s 8ms/step - loss: 42.0990 - accuracy: 0.0169 - val_loss: 36.8807 - val_accuracy: 0.0000e+00
# Epoch 2/100
# 24/24 [==============================] - 0s 2ms/step - loss: 30.4306 - accuracy: 0.0127 - val_loss: 27.2824 - val_accuracy: 0.0000e+00
# Epoch 3/100
# 24/24 [==============================] - 0s 2ms/step - loss: 22.7781 - accuracy: 0.0127 - val_loss: 20.9178 - val_accuracy: 0.0000e+00
# Epoch 4/100
# 24/24 [==============================] - 0s 2ms/step - loss: 17.4140 - accuracy: 0.0127 - val_loss: 15.9425 - val_accuracy: 0.0000e+00
# Epoch 5/100
# 24/24 [==============================] - 0s 2ms/step - loss: 13.2581 - accuracy: 0.0042 - val_loss: 11.9633 - val_accuracy: 0.0000e+00
# Epoch 6/100
# 24/24 [==============================] - 0s 2ms/step - loss: 10.0787 - accuracy: 0.0042 - val_loss: 9.1752 - val_accuracy: 0.0000e+00
# Epoch 7/100
# ...

# %%
dataset = pd.read_csv("diem-after-cleaning.csv")
# split into input (X) and output (Y) variables
dataset.drop(['Unnamed: 0'], axis=1, inplace=True)
dataset = dataset.values
X = dataset[:,0:3]
Y = dataset[:,3]
model = Sequential()
model.add(Dense(100,input_dim=3, activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.24, epochs=100, batch_size=20, verbose=0)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'vali'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
dataset = pd.read_csv("diem-after-cleaning.csv")
# split into input (X) and output (Y) variables
dataset.drop(['Unnamed: 0'], axis=1, inplace=True)
dataset = dataset.values
X = dataset[:,0:3]
Y = dataset[:,3]
model = Sequential()
model.add(Dense(5,input_dim=3, activation='relu'))
model.add(Dense(4,input_dim=3, activation='relu'))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
history = model.fit(X, Y, validation_split=0.2, epochs=100, batch_size=11, verbose=0)
print(history.history.keys())
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'vali'], loc='upper left')
plt.show()
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
