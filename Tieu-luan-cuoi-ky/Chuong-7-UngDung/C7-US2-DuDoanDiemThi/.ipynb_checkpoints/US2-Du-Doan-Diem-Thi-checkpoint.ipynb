# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data0 = pd.read_csv("lop70.csv")
data1 = pd.read_csv("lop71.csv")
data2 = pd.read_csv("lop72.csv")
data3 = pd.read_csv("lop73.csv")

# %% [markdown]
# Xóa cột họ tên của data 0, chuẩn hóa tên cột

# %%
data0.drop(['Họ Tên'], axis = 1, inplace=True)

# %%
data0.columns = ['P1', 'P2', 'P3', 'Thi']

# %% [markdown]
# ## Xử lý data1

# %%
data1
# Out:
#     ho_ten   10%   20%  20%.1   thi
# 0   71_011  6.50  6.50    6.0  6.50
# 1   71_012  5.50  5.50    6.0  5.00
# 2   71_013  6.50  7.00    7.0  6.75
# 3   71_014  7.25  5.50    7.0  6.00
# 4   71_021  7.50  5.00    6.0  6.00
# ..     ...   ...   ...    ...   ...
# 71  71_146  7.00  6.75    7.5  6.50
# 72  71_151  7.50  7.00    8.0  9.00
# 73  71_152  7.00  6.50    6.5  6.50
# 74  71_153  7.00  7.00    7.5  7.50
# 75  71_154  7.00  7.00    7.0   NaN
#
# [76 rows x 5 columns]

# %%
data1.drop(['ho_ten'], axis = 1, inplace=True)
data1.columns = ['P1', 'P2', 'P3', 'Thi']
# Out:
# P1     float64
# P2     float64
# P3     float64
# Thi    float64
# dtype: object

# %%
data2
# Out:
#     ho_ten    10%    20%  20%.1   thi
# 0   72_011  6.000  6.500   7.00  6.75
# 1   72_012  6.500  7.250   7.75  7.50
# 2   72_013  5.750  6.750   7.25  7.00
# 3   72_014  6.750  7.000   7.50  7.25
# 4   72_015  6.000  6.500   7.00  6.75
# ..     ...    ...    ...    ...   ...
# 72  72_151  7.375  6.500   7.50  7.00
# 73  72_152  7.250  6.750   7.00  7.00
# 74  72_153  7.125  6.750   6.75  7.00
# 75  72_154  7.750  6.375   7.50  7.00
# 76  72_155  7.875  6.125   6.75  7.00
#
# [77 rows x 5 columns]

# %%
data2.drop(['ho_ten'], axis = 1, inplace=True)
data2.columns = ['P1', 'P2', 'P3', 'Thi']
data2
# Out:
#        P1     P2    P3   Thi
# 0   6.000  6.500  7.00  6.75
# 1   6.500  7.250  7.75  7.50
# 2   5.750  6.750  7.25  7.00
# 3   6.750  7.000  7.50  7.25
# 4   6.000  6.500  7.00  6.75
# ..    ...    ...   ...   ...
# 72  7.375  6.500  7.50  7.00
# 73  7.250  6.750  7.00  7.00
# 74  7.125  6.750  6.75  7.00
# 75  7.750  6.375  7.50  7.00
# 76  7.875  6.125  6.75  7.00
#
# [77 rows x 4 columns]

# %%
print(data3.columns)
# Out:
# Index(['Unnamed: 0', '10%', '20%', 'BT bo sung', '20%.1', 'Thi'], dtype='object')

# %%
data3
# Out:
#    Unnamed: 0   10%   20%  BT bo sung  20%.1   Thi
# 0      32_011  7.25  6.50        6.00   6.50  6.75
# 1      32_012  7.00  7.50        5.00   7.50  7.00
# 2      32_013  7.00  7.25        5.25   7.25  7.00
# 3      32_014  6.50  7.00        5.25   7.00  6.50
# 4      32_015  7.50  7.00        5.00   7.00  7.25
# ..        ...   ...   ...         ...    ...   ...
# 64     32_151  5.50  6.75        6.75   6.75  6.50
# 65     32_152  7.00  7.00        6.00   6.50  6.00
# 66     32_153  4.00  7.00        6.00   6.50  6.00
# 67     32_154  7.50  7.00        8.00   8.00  7.00
# 68     32_155  3.50  3.00        5.50   5.50  5.00
#
# [69 rows x 6 columns]

# %%
data3.drop(['BT bo sung', '20%.1'], axis = 1, inplace=True)
data3
# Out:
#    Unnamed: 0   10%   20%   Thi
# 0      32_011  7.25  6.50  6.75
# 1      32_012  7.00  7.50  7.00
# 2      32_013  7.00  7.25  7.00
# 3      32_014  6.50  7.00  6.50
# 4      32_015  7.50  7.00  7.25
# ..        ...   ...   ...   ...
# 64     32_151  5.50  6.75  6.50
# 65     32_152  7.00  7.00  6.00
# 66     32_153  4.00  7.00  6.00
# 67     32_154  7.50  7.00  7.00
# 68     32_155  3.50  3.00  5.00
#
# [69 rows x 4 columns]

# %%
data3.columns=['P1', 'P2', 'P3', 'Thi']
data3
# Out:
#         P1    P2    P3   Thi
# 0   32_011  7.25  6.50  6.75
# 1   32_012  7.00  7.50  7.00
# 2   32_013  7.00  7.25  7.00
# 3   32_014  6.50  7.00  6.50
# 4   32_015  7.50  7.00  7.25
# ..     ...   ...   ...   ...
# 64  32_151  5.50  6.75  6.50
# 65  32_152  7.00  7.00  6.00
# 66  32_153  4.00  7.00  6.00
# 67  32_154  7.50  7.00  7.00
# 68  32_155  3.50  3.00  5.00
#
# [69 rows x 4 columns]

# %%
data3.dtypes
# Out:
# P1     float64
# P2     float64
# P3     float64
# Thi    float64
# dtype: object

# %%
data = pd.concat([data0, data1, data2, data3], axis=0)
data = data.reset_index(drop=True)
data
# Out:
#      Họ Tên    10%   20%  20%.1   Thi ho_ten  thi   P1    P2    P3
# 0    31_011  8.375  7.25    8.5   9.0    NaN  NaN  NaN   NaN   NaN
# 1    31_012  8.250  7.25    8.5   9.0    NaN  NaN  NaN   NaN   NaN
# 2    31_013  8.500  7.50    8.5  10.0    NaN  NaN  NaN   NaN   NaN
# 3    31_014  4.000  7.25    8.5   9.0    NaN  NaN  NaN   NaN   NaN
# 4    31_015  8.750  7.50    8.5   9.5    NaN  NaN  NaN   NaN   NaN
# ..      ...    ...   ...    ...   ...    ...  ...  ...   ...   ...
# 292     NaN    NaN   NaN    NaN   6.5    NaN  NaN  5.5  6.75  6.75
# 293     NaN    NaN   NaN    NaN   6.0    NaN  NaN  7.0  7.00  6.25
# 294     NaN    NaN   NaN    NaN   6.0    NaN  NaN  4.0  7.00  6.25
# 295     NaN    NaN   NaN    NaN   7.0    NaN  NaN  7.5  7.00  8.00
# 296     NaN    NaN   NaN    NaN   5.0    NaN  NaN  3.5  3.00  5.50
#
# [297 rows x 10 columns]

# %%
data.isnull().sum()
# Out:
# P1     0
# P2     0
# P3     0
# Thi    0
# dtype: int64

# %%
data = data[(data.P1!=np.nan) & (data.P2!=np.nan) & (data.P3!=np.nan) & (data.Thi!=np.nan)]
data
# Out:
#         P1    P2    P3   Thi
# 0    8.375  7.25  8.50   9.0
# 1     8.25  7.25  8.50   9.0
# 2      8.5   7.5  8.50  10.0
# 3      4.0  7.25  8.50   9.0
# 4     8.75   7.5  8.50   9.5
# ..     ...   ...   ...   ...
# 292    5.5  6.75  6.75   6.5
# 293      7     7  6.25   6.0
# 294      4     7  6.25   6.0
# 295    7.5     7  8.00   7.0
# 296    3.5     3  5.50   5.0
#
# [297 rows x 4 columns]

# %%
data['P1'] = data['P1'].replace(np.nan, data['P1'].mean)
data['P2'] = data['P2'].replace(np.nan, data['P2'].mean)
data['P3'] = data['P3'].replace(np.nan, data['P3'].mean)
data['Thi'] = data['Thi'].replace(np.nan, data['Thi'].mean)

# %%
data.duplicated(keep=False)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 292    False
# 293    False
# 294    False
# 295    False
# 296    False
# Length: 297, dtype: bool

# %%
data.drop_duplicates(keep='first')
data
# Out:
#         P1    P2    P3   Thi
# 0    8.375  7.25   8.5   9.0
# 1     8.25  7.25   8.5   9.0
# 2      8.5   7.5   8.5  10.0
# 3      4.0  7.25   8.5   9.0
# 4     8.75   7.5   8.5   9.5
# ..     ...   ...   ...   ...
# 292    5.5  6.75  6.75   6.5
# 293      7     7  6.25   6.0
# 294      4     7  6.25   6.0
# 295    7.5     7   8.0   7.0
# 296    3.5     3   5.5   5.0
#
# [297 rows x 4 columns]

# %%
data.fillna(data.mean(numeric_only=True), inplace = True) # replace NaN with the mean
data.isnull().sum()
# Out:
# P1     0
# P2     0
# P3     0
# Thi    0
# dtype: int64

# %%
data.to_csv('diem-after-cleaning.csv')

# %%
print(data.dtypes)
# Out:
# P1     object
# P2     object
# P3     object
# Thi    object
# dtype: object

# %%
data = pd.read_csv('diem-after-cleaning.csv')

# %% [markdown]
# # Sử dụng machine learning cơ bản

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = data[['P1','P2','P3']].values
y = data[['Thi']].values

# %%
X
# Out:
# array([['8.375', '7.25', '8.5'],
#        ['8.25', '7.25', '8.5'],
#        ['8.5', '7.5', '8.5'],
#        ['4.0', '7.25', '8.5'],
#        ['8.75', '7.5', '8.5'],
#        ['7.75', '7.75', '7.75'],
#        ['7.0', '3.0', '7.0'],
#        ['7.5', '7.5', '7.5'],
#        ['7.0', '7.0', '7.0'],
#        ['7.25', '7.0', '7.0'],
#        ['7.625', '7.25', '7.0'],
#        ['7.75', '7.25', '7.25'],
#        ['7.625', '7.375', '7.75'],
#        ['7.5', '6.5', '6.75'],
#        ['7.5', '7.25', '7.0'],
#        ['8.5', '8.0', '9.0'],
#        ['8.125', '7.625', '7.5'],
#        ['8.125', '7.625', '7.75'],
#        ['8.25', '7.875', '8.0'],
#        ['8.0', '7.25', '8.25'],
#        ['7.75', '7.0', '6.0'],
#        ['8.25', '7.25', '6.5'],
#        ['3.5', '0.0', '0.0'],
#        ['8.75', '8.0', '9.0'],
#        ['7.75', '7.25', '6.75'],
#        ['8.0', '7.0', '7.0'],
#        ['7.75', '7.625', '7.5'],
#        ['7.25', '7.5', '7.0'],
#        ['3.75', '7.0', '7.0'],
#        ['8.0', '7.125', '7.0'],
#        ['7.75', '7.0', '7.0'],
#        ['8.125', '7.25', '7.0'],
#        ['8.5', '3.75', '7.0'],
#        ['8.0', '3.75', '7.0'],
#        ['8.375', '7.675', '7.0'],
#        ['7.5', '7.5', '7.5'],
#        ['8.25', '7.75', '7.0'],
#        ['7.0', '7.0', '7.0'],
#        ['8.25', '8.0', '7.5'],
#        ['7.75', '7.0', '7.0'],
#        ['8.25', '7.25', '7.0'],
#        ['7.75', '7.0', '6.5'],
#        ['7.4', '6.75', '6.0'],
#        ['7.5', '6.0', '6.0'],
#        ['0.0', '0.0', '0.0'],
#        ['7.75', '6.5', '7.5'],
#        ['8.0', '7.25', '7.5'],
#        ['8.25', '8.25', '8.5'],
#        ['8.0', '7.0', '7.5'],
#        ['8.25', '7.5', '7.5'],
#        ['8.0', '7.875', '6.5'],
#        ['8.25', '7.5', '6.5'],
#        ['7.75', '7.5', '7.0'],
#        ['8.0', '7.25', '6.5'],
#        ['8.125', '7.875', '6.0'],
#        ['7.5', '6.0', '7.0'],
#        ['7.5', '7.625', '8.5'],
#        ['7.25', '6.5', '7.5'],
#        ['7.75', '8.0', '9.5'],
#        ['7.125', '7.0', '7.5'],
#        ['0.0', '0.0', '0.0'],
#        ['7.625', '7.375', '7.0'],
#        ['0.0', '0.0', '0.0'],
#        ['0.0', '7.75', '7.5'],
#        ['7.5', '7.0', '7.0'],
#        ['7.0', '6.25', '6.0'],
#        ['0.0', '0.0', '0.0'],
#        ['0.5', '5.75', '5.0'],
#        ['7.375', '7.375', '6.5'],
#        ['3.75', '2.625', '6.0'],
#        ['8.25', '7.75', '8.25'],
#        ['3.5', '3.25', '6.0'],
#        ['7.25', '6.5', '6.0'],
#        ['7.75', '3.5', '7.5'],
#        ['0.0', '0.0', '0.0'],
#        ['6.5', '6.5', '6.0'],
#        ['5.5', '5.5', '6.0'],
#        ['6.5', '7.0', '7.0'],
#        ['7.25', '5.5', '7.0'],
#        ['7.5', '5.0', '6.0'],
#        ['8.0', '6.0', '6.0'],
#        ['9.0', '8.0', '8.0'],
#        ['7.5', '5.0', '6.0'],
#        ['6.5', '6.0', '6.0'],
#        ['8.0', '6.5', '7.0'],
#        ['8.0', '7.0', '7.0'],
#        ['8.0', '7.0', '7.0'],
#        ['<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      8.375\n1       8.25\n2        8.5\n3        4.0\n4       8.75\n       ...  \n292      5.5\n293        7\n294        4\n295      7.5\n296      3.5\nName: P1, Length: 297, dtype: object>',
#         '<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      7.25\n1      7.25\n2       7.5\n3      7.25\n4       7.5\n       ... \n292    6.75\n293       7\n294       7\n295       7\n296       3\nName: P2, Length: 297, dtype: object>',
#         '<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      8.50\n1      8.50\n2      8.50\n3      8.50\n4      8.50\n       ... \n292    6.75\n293    6.25\n294    6.25\n295    8.00\n296    5.50\nName: P3, Length: 297, dtype: float64>'],
#        ['<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      8.375\n1       8.25\n2        8.5\n3        4.0\n4       8.75\n       ...  \n292      5.5\n293        7\n294        4\n295      7.5\n296      3.5\nName: P1, Length: 297, dtype: object>',
#         '<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      7.25\n1      7.25\n2       7.5\n3      7.25\n4       7.5\n       ... \n292    6.75\n293       7\n294       7\n295       7\n296       3\nName: P2, Length: 297, dtype: object>',
#         '<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      8.50\n1      8.50\n2      8.50\n3      8.50\n4      8.50\n       ... \n292    6.75\n293    6.25\n294    6.25\n295    8.00\n296    5.50\nName: P3, Length: 297, dtype: float64>'],
#        ['10.0', '6.5', '8.0'],
#        ['10.0', '8.0', '8.0'],
#        ['10.0', '6.5', '7.5'],
#        ['7.0', '6.0', '7.0'],
#        ['10.0', '6.75', '8.0'],
#        ['10.0', '6.5', '8.0'],
#        ['7.0', '6.0', '6.5'],
#        ['7.12', '6.25', '7.0'],
#        ['7.75', '6.25', '7.25'],
#        ['7.35', '6.0', '7.0'],
#        ['7.5', '5.5', '6.5'],
#        ['7.12', '5.75', '6.5'],
#        ['10.0', '6.0', '6.5'],
#        ['10.0', '6.5', '6.5'],
#        ['7.0', '5.0', '6.5'],
#        ['10.0', '6.0', '6.5'],
#        ['10.0', '6.5', '6.5'],
#        ['9.0', '6.25', '7.0'],
#        ['8.0', '6.0', '6.5'],
#        ['9.0', '7.25', '7.5'],
#        ['8.0', '6.75', '6.5'],
#        ['8.0', '6.5', '6.0'],
#        ['8.0', '6.0', '5.5'],
#        ['7.5', '6.5', '6.25'],
#        ['8.5', '5.75', '6.5'],
#        ['8.0', '6.0', '6.5'],
#        ['7.0', '6.0', '6.0'],
#        ['7.0', '7.0', '6.0'],
#        ['7.25', '6.75', '6.5'],
#        ['7.0', '6.5', '6.0'],
#        ['5.5', '5.0', '5.0'],
#        ['6.0', '6.5', '6.0'],
#        ['9.0', '7.0', '6.5'],
#        ['9.0', '7.0', '6.0'],
#        ['7.0', '6.5', '6.0'],
#        ['9.0', '7.0', '6.5'],
#        ['9.0', '7.0', '6.0'],
#        ['8.0', '6.75', '7.0'],
#        ['8.0', '6.75', '8.0'],
#        ['8.0', '6.5', '7.5'],
#        ['8.25', '5.0', '8.0'],
#        ['7.75', '6.5', '7.0'],
#        ['9.0', '7.5', '7.0'],
#        ['8.0', '6.5', '6.5'],
#        ['8.0', '7.0', '7.0'],
#        ['8.0', '7.0', '7.0'],
#        ['8.0', '7.0', '7.0'],
#        ['7.5', '7.5', '8.0'],
#        ['8.0', '7.0', '8.0'],
#        ['8.5', '8.25', '8.0'],
#        ['8.5', '7.0', '6.5'],
#        ['8.5', '7.5', '7.5'],
#        ['7.0', '7.0', '7.5'],
#        ['7.0', '7.25', '7.0'],
#        ['7.0', '3.25', '7.25'],
#        ['7.0', '7.5', '8.0'],
#        ['7.0', '7.25', '7.25'],
#        ['7.0', '6.75', '7.5'],
#        ['7.5', '7.0', '8.0'],
#        ['7.0', '6.5', '6.5'],
#        ['7.0', '7.0', '7.5'],
#        ['7.0', '7.0', '7.0'],
#        ['6.0', '6.5', '7.0'],
#        ['6.5', '7.25', '7.75'],
#        ['5.75', '6.75', '7.25'],
#        ['6.75', '7.0', '7.5'],
#        ['6.0', '6.5', '7.0'],
#        ['8.38', '7.0', '6.75'],
#        ['8.88', '7.0', '6.0'],
#        ['8.13', '6.5', '6.0'],
#        ['7.88', '7.0', '6.0'],
#        ['8.25', '7.5', '6.5'],
#        ['8.75', '8.0', '7.0'],
#        ['3.5', '6.75', '7.0'],
#        ['7.5', '8.0', '7.0'],
#        ['7.0', '7.25', '7.0'],
#        ['7.0', '7.125', '6.5'],
#        ['7.0', '7.5', '7.0'],
#        ['8.0', '6.5', '6.0'],
#        ['7.6', '7.0', '7.0'],
#        ['6.75', '5.5', '6.5'],
#        ['7.4', '5.75', '5.8'],
#        ['6.9', '6.75', '5.0'],
#        ['7.75', '6.6', '6.0'],
#        ['7.0', '7.0', '7.5'],
#        ['7.0', '7.4', '7.25'],
#        ['7.25', '6.5', '8.0'],
#        ['6.825', '7.0', '7.0'],
#        ['7.25', '7.25', '7.5'],
#        ['7.25', '6.5', '6.5'],
#        ['6.325', '6.0', '6.25'],
#        ['7.0', '6.0', '6.0'],
#        ['6.5', '6.0', '6.75'],
#        ['7.25', '6.5', '6.75'],
#        ['7.125', '6.75', '6.0'],
#        ['7.625', '7.125', '6.0'],
#        ['7.625', '6.8', '7.0'],
#        ['6.75', '7.25', '7.0'],
#        ['7.0', '6.875', '7.0'],
#        ['7.375', '7.0', '6.75'],
#        ['6.875', '7.0', '6.75'],
#        ['7.25', '6.875', '7.25'],
#        ['6.875', '7.125', '7.0'],
#        ['7.125', '7.125', '7.0'],
#        ['7.25', '3.375', '7.0'],
#        ['6.5', '6.75', '6.5'],
#        ['6.5', '6.875', '6.75'],
#        ['3.0', '0.0', '0.0'],
#        ['7.125', '6.875', '7.25'],
#        ['7.75', '8.375', '8.0'],
#        ['7.5', '8.125', '8.0'],
#        ['7.125', '7.75', '7.5'],
#        ['7.75', '7.625', '7.0'],
#        ['7.375', '8.125', '8.0'],
#        ['0.0', '0.0', '0.0'],
#        ['7.125', '7.5', '7.5'],
#        ['6.875', '7.125', '7.5'],
#        ['6.625', '6.5', '6.5'],
#        ['3.75', '3.375', '6.5'],
#        ['7.75', '7.875', '8.0'],
#        ['7.5', '7.625', '7.75'],
#        ['7.125', '7.625', '7.5'],
#        ['7.125', '7.375', '7.25'],
#        ['6.75', '8.75', '9.0'],
#        ['7.5', '6.0', '6.5'],
#        ['7.5', '6.75', '6.25'],
#        ['7.25', '6.5', '6.5'],
#        ['7.875', '6.25', '6.5'],
#        ['8.25', '8.0', '8.0'],
#        ['7.125', '6.5', '6.25'],
#        ['7.25', '0.0', '0.0'],
#        ['6.875', '6.5', '6.0'],
#        ['6.375', '6.375', '6.0'],
#        ['7.25', '6.5', '6.5'],
#        ['7.375', '6.5', '7.5'],
#        ['7.25', '6.75', '7.0'],
#        ['7.125', '6.75', '6.75'],
#        ['7.75', '6.375', '7.5'],
#        ['7.875', '6.125', '6.75'],
#        ['7.25', '6.5', '6.25'],
#        ['7', '7.5', '6.25'],
#        ['7', '7.25', '6.25'],
#        ['6.5', '7', '6.125'],
#        ['7.5', '7', '6.0'],
#        ['8', '6.75', '7.0'],
#        ['7.5', '6.5', '6.0'],
#        ['7.5', '6.5', '6.0'],
#        ['7', '6.25', '6.125'],
#        ['7.5', '6', '5.75'],
#        ['9', '7.375', '8.0'],
#        ['9.5', '7.75', '8.25'],
#        ['9.25', '8.25', '8.75'],
#        ['9.375', '7.375', '8.0'],
#        ['9.125', '7.25', '8.0'],
#        ['7,5', '6', '7.0'],
#        ['8', '6,5', '6.75'],
#        ['8', '6,5', '6.625'],
#        ['8', '6,75', '6.75'],
#        ['7,5', '6,75', '7.0'],
#        ['7', '6.25', '7.125'],
#        ['6.5', '6.5', '7.125'],
#        ['6.75', '6.75', '7.125'],
#        ['6.5', '6', '6.875'],
#        ['6', '6.25', '7.0'],
#        ['8', '7.25', '6.875'],
#        ['9', '8', '7.0'],
#        ['7.75', '6.8', '6.375'],
#        ['7.25', '6.25', '6.0'],
#        ['7.25', '6.125', '6.0'],
#        ['7.25', '6', '7.0'],
#        ['7.25', '6.75', '7.25'],
#        ['7', '3.123', '7.5'],
#        ['0', '5.5', '7.125'],
#        ['7.25', '6.5', '7.0'],
#        ['8.125', '7.375', '7.25'],
#        ['8.75', '3.75', '7.25'],
#        ['8.5', '3.5', '6.875'],
#        ['8.5', '7.875', '7.625'],
#        ['8.75', '7.5', '8.0'],
#        ['8.5', '6.75',
#         '<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      8.50\n1      8.50\n2      8.50\n3      8.50\n4      8.50\n       ... \n292    6.75\n293    6.25\n294    6.25\n295    8.00\n296    5.50\nName: P3, Length: 297, dtype: float64>'],
#        ['9', '6.75',
#         '<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      8.50\n1      8.50\n2      8.50\n3      8.50\n4      8.50\n       ... \n292    6.75\n293    6.25\n294    6.25\n295    8.00\n296    5.50\nName: P3, Length: 297, dtype: float64>'],
#        ['9', '7',
#         '<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      8.50\n1      8.50\n2      8.50\n3      8.50\n4      8.50\n       ... \n292    6.75\n293    6.25\n294    6.25\n295    8.00\n296    5.50\nName: P3, Length: 297, dtype: float64>'],
#        ['8.5', '6.75',
#         '<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      8.50\n1      8.50\n2      8.50\n3      8.50\n4      8.50\n       ... \n292    6.75\n293    6.25\n294    6.25\n295    8.00\n296    5.50\nName: P3, Length: 297, dtype: float64>'],
#        ['8', '7',
#         '<bound method NDFrame._add_numeric_operations.<locals>.mean of 0      8.50\n1      8.50\n2      8.50\n3      8.50\n4      8.50\n       ... \n292    6.75\n293    6.25\n294    6.25\n295    8.00\n296    5.50\nName: P3, Length: 297, dtype: float64>'],
#        ['7.75', '7', '6.875'],
#        ['7.75', '7', '7.0'],
#        ['7.5', '7', '7.0'],
#        ['7.5', '7', '7.25'],
#        ['7.75', '8.25', '7.75'],
#        ['8.25', '7.75', '7.0'],
#        ['7.5', '7.25', '6.75'],
#        ['7.625', '7.25', '6.75'],
#        ['7', '6.875', '6.25'],
#        ['9', '8.75', '9.0'],
#        ['7.25', '7.75', '7.5'],
#        ['7', '3', '6.75'],
#        ['6.5', '7', '6.625'],
#        ['8.25', '7.75', '7.75'],
#        ['8.25', '3.5', '7.25'],
#        ['7.75', '7', '7.25'],
#        ['8', '7.25', '7.25'],
#        ['7.75', '7', '7.5'],
#        ['7.75', '7.25', '7.875'],
#        ['5.5', '6.75', '6.75'],
#        ['7', '7', '6.25'],
#        ['4', '7', '6.25'],
#        ['7.5', '7', '8.0'],
#        ['3.5', '3', '5.5']], dtype=object)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [104], in <cell line: 2>()
#       1 model = LinearRegression()
# ----> 2 model.fit(X_train, y_train)
#
# File D:\Anaconda\lib\site-packages\sklearn\linear_model\_base.py:662, in LinearRegression.fit(self, X, y, sample_weight)
#     658 n_jobs_ = self.n_jobs
#     660 accept_sparse = False if self.positive else ["csr", "csc", "coo"]
# --> 662 X, y = self._validate_data(
#     663     X, y, accept_sparse=accept_sparse, y_numeric=True, multi_output=True
#     664 )
#     666 if sample_weight is not None:
#     667     sample_weight = _check_sample_weight(sample_weight, X, dtype=X.dtype)
#
# File D:\Anaconda\lib\site-packages\sklearn\base.py:581, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     579         y = check_array(y, **check_y_params)
#     580     else:
# --> 581         X, y = check_X_y(X, y, **check_params)
#     582     out = X, y
#     584 if not no_val_X and check_params.get("ensure_2d", True):
#
# File D:\Anaconda\lib\site-packages\sklearn\utils\validation.py:964, in check_X_y(X, y, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, estimator)
#     961 if y is None:
#     962     raise ValueError("y cannot be None")
# --> 964 X = check_array(
#     965     X,
#     966     accept_sparse=accept_sparse,
#     967     accept_large_sparse=accept_large_sparse,
#     968     dtype=dtype,
#     969     order=order,
#     970     copy=copy,
#     971     force_all_finite=force_all_finite,
#     972     ensure_2d=ensure_2d,
#     973     allow_nd=allow_nd,
#     974     ensure_min_samples=ensure_min_samples,
#     975     ensure_min_features=ensure_min_features,
#     976     estimator=estimator,
#     977 )
#     979 y = _check_y(y, multi_output=multi_output, y_numeric=y_numeric)
#     981 check_consistent_length(X, y)
#
# File D:\Anaconda\lib\site-packages\sklearn\utils\validation.py:746, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator)
#     744         array = array.astype(dtype, casting="unsafe", copy=False)
#     745     else:
# --> 746         array = np.asarray(array, order=order, dtype=dtype)
#     747 except ComplexWarning as complex_warning:
#     748     raise ValueError(
#     749         "Complex data not supported\n{}\n".format(array)
#     750     ) from complex_warning
#
# ValueError: could not convert string to float: '6,5'
